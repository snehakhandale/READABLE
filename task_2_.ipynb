# %% [markdown]
# <a href="https://colab.research.google.com/github/snehakhandale/READABLE/blob/main/task_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("/content/cat image.jpg")
plt.imshow(img)

# %%
color_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(color_img)

# %%
from IPython.display import display
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_gray)

# %%
img_gray_inv=225-img_gray
plt.imshow(img_gray_inv)

# %%
img_blur=cv2.GaussianBlur(img_gray_inv,ksize=(23,23),sigmaX=0,sigmaY=0)
plt.imshow(img_blur)

# %%
def dodgeV2(image,mask):
  return(cv2.divide(image,160+mask,scale=162))

def dodgeV2(image,mask):
  return(255-cv2.divide(255+image,160+mask,scale=162))

img_blend=dodgeV2(img_gray,img_blur)

# %%
plt.imshow(img_blend)

# %%
plt.imshow(color_img)

# %%
cv2.imwrite('result.jpg',img_blend)
# Out:
# True
